# %% [markdown]
# ># Python Programming Assignment
#
#
#
#
# Total Marks = 100
#
# > ## Data Cleaning and Assembly
#
#
#
# * **Student Name** : Arun Joy
# * **Section**      : Data Analytics
# * **Student ID** : 8871745

# %% [markdown]
# Download the file "Python Assignment 3 - DataFrame Cleaning.xlsx”  .  Use appropriate data cleaning techniques and methods in Pandas to convert the raw file into  clean data structure ” as shown in the reference file "Your Assignment3 output file should look like this.xlsx" and answer the questions below.
#
# Your answers should be accurate.  All cleaning and manipulation should be done in Python only. Be careful for subtotals in the data to avoid double counting.

# %% [markdown]
# -----------------------------------

# %% [markdown]
# **import the required packages and the question file in the cell below**

# %%
import pandas as pd #importing Pandas
import numpy as np #importing numpy

# %%
data = pd.read_excel(r'C:\Users\aj149\Downloads\Python Assignment 3 - DataFrame Cleaning.xlsx', sheet_name='A3',skiprows=4)
print(data)
# Out:
#      Player Code                                    Player Name Match Number  \
# 0                NaN                                        NaN          NaN
# 1              45234                             Maud Nicholson           M1
# 2                NaN                                        NaN           M3
# 3                NaN                                                      M5
# 4                NaN                                        NaN           M6
# ..               ...                                        ...          ...
# 219              NaN                                        NaN           M2
# 220              NaN                                        NaN           M3
# 221              NaN                                        NaN           M4
# 222              NaN                                        NaN          NaN
# 223              NaN  Gran Total Stats of All the above players          NaN
#
# ...

# %%
data
# Out:
#      Player Code                                    Player Name Match Number  \
# 0                NaN                                        NaN          NaN
# 1              45234                             Maud Nicholson           M1
# 2                NaN                                        NaN           M3
# 3                NaN                                                      M5
# 4                NaN                                        NaN           M6
# ..               ...                                        ...          ...
# 219              NaN                                        NaN           M2
# 220              NaN                                        NaN           M3
# 221              NaN                                        NaN           M4
# 222              NaN                                        NaN          NaN
# 223              NaN  Gran Total Stats of All the above players          NaN
#
# ...

# %%
data = data.dropna(how= 'all', axis = 0 ) # Deleting totally blank rows
data = data.dropna(how= 'all', axis = 1 ) # Deleting totally blank columns

# %%
data
# Out:
#      Player Code                                    Player Name Match Number  \
# 1              45234                             Maud Nicholson           M1
# 2                NaN                                        NaN           M3
# 3                NaN                                                      M5
# 4                NaN                                        NaN           M6
# 5                NaN                          Total Player Runs          NaN
# ..               ...                                        ...          ...
# 218           787511                                   Raj Webb           M1
# 219              NaN                                        NaN           M2
# 220              NaN                                        NaN           M3
# 221              NaN                                        NaN           M4
# 223              NaN  Gran Total Stats of All the above players          NaN
#
# ...

# %%
data.columns
# Out:
# Index([' Player Code    ', '  Player Name', 'Match Number',
#        'Number of Wickets Taken  ', '   Number of Runs '],
#       dtype='object')

# %%
data.columns = data.columns.str.strip() # stripping spaces from column names and reassigning the clean column names to the dataset

# %%
data.columns
# Out:
# Index(['Player Code', 'Player Name', 'Match Number', 'Number of Wickets Taken',
#        'Number of Runs'],
#       dtype='object')

# %%
data
# Out:
#     Player Code                                Player Name Match Number  \
# 1         45234                             Maud Nicholson           M1
# 2           NaN                                        NaN           M3
# 3           NaN                                                      M5
# 4           NaN                                        NaN           M6
# 5           NaN                          Total Player Runs          NaN
# ..          ...                                        ...          ...
# 218      787511                                   Raj Webb           M1
# 219         NaN                                        NaN           M2
# 220         NaN                                        NaN           M3
# 221         NaN                                        NaN           M4
# 223         NaN  Gran Total Stats of All the above players          NaN
#
#      Number of Wickets Taken  Number of Runs
# 1                        2.0            82.0
# ...

# %%
data['Number of Wickets Taken'].sum()
# Out:
# 536.0

# %%
data['Number of Runs'].sum()
# Out:
# 18868.0

# %%
data = data.replace(' ', None ) # replacing any spaces with Null values so that we can use fillna method

# %%
data
# Out:
#     Player Code                                Player Name Match Number  \
# 1         45234                             Maud Nicholson           M1
# 2           NaN                                        NaN           M3
# 3           NaN                                       None           M5
# 4           NaN                                        NaN           M6
# 5           NaN                          Total Player Runs          NaN
# ..          ...                                        ...          ...
# 218      787511                                   Raj Webb           M1
# 219         NaN                                        NaN           M2
# 220         NaN                                        NaN           M3
# 221         NaN                                        NaN           M4
# 223         NaN  Gran Total Stats of All the above players          NaN
#
#      Number of Wickets Taken  Number of Runs
# 1                        2.0            82.0
# ...

# %%
data=data.dropna(subset=['Match Number','Number of Wickets Taken']) #Deleting rows with value null for Match Number

# %%
data
# Out:
#     Player Code     Player Name Match Number  Number of Wickets Taken  \
# 1         45234  Maud Nicholson           M1                      2.0
# 2           NaN             NaN           M3                      3.0
# 3           NaN            None           M5                      0.0
# 4           NaN             NaN           M6                      1.0
# 6          4578    Logan Thomas           M1                      0.0
# ..          ...             ...          ...                      ...
# 216     7845522    Tori Knowles           M1                      2.0
# 218      787511        Raj Webb           M1                      1.0
# 219         NaN             NaN           M2                      4.0
# 220         NaN             NaN           M3                      0.0
# 221         NaN             NaN           M4                      1.0
#
#      Number of Runs
# 1              82.0
# 2              71.0
# 3              36.0
# 4              76.0
# ...

# %%
data=data.replace(" ",np.nan) #changing any cell with single space if any

# %%
data
# Out:
#     Player Code     Player Name Match Number  Number of Wickets Taken  \
# 1         45234  Maud Nicholson           M1                      2.0
# 2           NaN             NaN           M3                      3.0
# 3           NaN            None           M5                      0.0
# 4           NaN             NaN           M6                      1.0
# 6          4578    Logan Thomas           M1                      0.0
# ..          ...             ...          ...                      ...
# 216     7845522    Tori Knowles           M1                      2.0
# 218      787511        Raj Webb           M1                      1.0
# 219         NaN             NaN           M2                      4.0
# 220         NaN             NaN           M3                      0.0
# 221         NaN             NaN           M4                      1.0
#
#      Number of Runs
# 1              82.0
# 2              71.0
# 3              36.0
# 4              76.0
# ...

# %%
data=data.dropna(subset=['Match Number','Number of Wickets Taken']) #Deleting rows with value null for Match Number

# %%
data
# Out:
#     Player Code     Player Name Match Number  Number of Wickets Taken  \
# 1         45234  Maud Nicholson           M1                      2.0
# 2           NaN             NaN           M3                      3.0
# 3           NaN            None           M5                      0.0
# 4           NaN             NaN           M6                      1.0
# 6          4578    Logan Thomas           M1                      0.0
# ..          ...             ...          ...                      ...
# 216     7845522    Tori Knowles           M1                      2.0
# 218      787511        Raj Webb           M1                      1.0
# 219         NaN             NaN           M2                      4.0
# 220         NaN             NaN           M3                      0.0
# 221         NaN             NaN           M4                      1.0
#
#      Number of Runs
# 1              82.0
# 2              71.0
# 3              36.0
# 4              76.0
# ...

# %%
data=data.fillna(method='ffill') #forward fill the values

# %%
data
# Out:
#      Player Code     Player Name Match Number  Number of Wickets Taken  \
# 1          45234  Maud Nicholson           M1                      2.0
# 2          45234  Maud Nicholson           M3                      3.0
# 3          45234  Maud Nicholson           M5                      0.0
# 4          45234  Maud Nicholson           M6                      1.0
# 6           4578    Logan Thomas           M1                      0.0
# ..           ...             ...          ...                      ...
# 216      7845522    Tori Knowles           M1                      2.0
# 218       787511        Raj Webb           M1                      1.0
# 219       787511        Raj Webb           M2                      4.0
# 220       787511        Raj Webb           M3                      0.0
# 221       787511        Raj Webb           M4                      1.0
#
#      Number of Runs
# 1              82.0
# 2              71.0
# 3              36.0
# 4              76.0
# ...

# %%
output = pd.ExcelWriter(r'C:\Users\aj149\Downloads\A3Result.xlsx', engine='xlsxwriter') #saving as excel
data.to_excel(output)
output.save()

# %%
import pandas as pd #importing Pandas
import numpy as np #importing numpy

# %%
data = pd.read_excel(r'C:\Users\aj149\Downloads\A3Result.xlsx', sheet_name='Sheet1')
print(data)
# Out:
#      Unnamed: 0  Player Code     Player Name Match Number  \
# 0             1        45234  Maud Nicholson           M1
# 1             2        45234  Maud Nicholson           M3
# 2             3        45234  Maud Nicholson           M5
# 3             4        45234  Maud Nicholson           M6
# 4             6         4578    Logan Thomas           M1
# ..          ...          ...             ...          ...
# 138         216      7845522    Tori Knowles           M1
# 139         218       787511        Raj Webb           M1
# 140         219       787511        Raj Webb           M2
# 141         220       787511        Raj Webb           M3
# 142         221       787511        Raj Webb           M4
#
#      Number of Wickets Taken  Number of Runs
# 0                          2              82
# 1                          3              71
# 2                          0              36
# 3                          1              76
# ...

# %%
data
# Out:
#      Unnamed: 0  Player Code     Player Name Match Number  \
# 0             1        45234  Maud Nicholson           M1
# 1             2        45234  Maud Nicholson           M3
# 2             3        45234  Maud Nicholson           M5
# 3             4        45234  Maud Nicholson           M6
# 4             6         4578    Logan Thomas           M1
# ..          ...          ...             ...          ...
# 138         216      7845522    Tori Knowles           M1
# 139         218       787511        Raj Webb           M1
# 140         219       787511        Raj Webb           M2
# 141         220       787511        Raj Webb           M3
# 142         221       787511        Raj Webb           M4
#
#      Number of Wickets Taken  Number of Runs
# 0                          2              82
# 1                          3              71
# 2                          0              36
# 3                          1              76
# ...

# %% [markdown]
# #### Q1) Paste your entire cleaning code that you used to convert the raw file to the clean file in the code cell below **and also explain clearly what each line of the code is doing by putting comments in your code** **(50 marks)**
#
# Note : Your entire cleaning code should be in the one cell given below
#
# for example,
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ----------------------------------------------------------

# %% [markdown]
# #### Write the analysis code that lead to the answer of each of the following questions in the single cell below each question.

# %% [markdown]
# ## Q2) What is the grand total number of wickets taken by all the players ?
# **10 marks**

# %%
total_wickets = data['Number of Wickets Taken'].sum() #Total number of wickets taken

# %%
total_wickets
# Out:
# 268.0

# %% [markdown]
# ## Q3) What is the grand total number of runs made in all the matches  ?
# **10 marks**

# %%
total_runs = data['Number of Runs'].sum() #Total number of runs made

# %%
total_runs
# Out:
# 7516.0

# %% [markdown]
# ## Q4) Using DataFrame Groupby method show the average number of runs made in **each** Match (M1 till M8)
# **20 marks**

# %%
average_runs_per_match = data.groupby('Match Number')['Number of Runs'].mean() #Average runs per match for each match number

# %%
average_runs_per_match
# Out:
# Match Number
# M1    54.893939
# M2    43.166667
# M3    49.127660
# M4    19.000000
# M5    59.157895
# M6    41.500000
# M7    68.000000
# M8    31.000000
# Name: Number of Runs, dtype: float64

# %% [markdown]
# ## Q5) Suppose you have two dataframes represented by variable names A and B.
#
# **Note: Just write the correct syntax of your code for each question below. You dont need to actually create the dataframe here.**

# %% [markdown]
# 5a) How would you write a code that will concat these two dataframes horizontally (column concatenation) ?
#
# 05 marks

# %%
df_concat = pd.concat([df1, df2], axis=1)

# %% [markdown]
# 5b) Write the code below to merge dataframes A and B if the primary key column in dataframe A is called "Product Codes" and foreign key column in dataframe B is called "Product IDs".
#
# 05 marks

# %%
df_merge = pd.merge(A, B, left_on='Product Codes', right_on='Product IDs')
